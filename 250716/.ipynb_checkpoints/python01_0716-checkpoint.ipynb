# %% [markdown]
# json 데이터는 바로 쓸 수 없고 한번 변환 해준 뒤 값을 사용할 수 있다. import json / json.loads

# %%
import json

data = """
{
    "id":"01", "language":"python", "edittion":"third", "author":"David",
    "history":
        [
            {
                "date":"2025-07-16",
                "item":"iPhone"
            },
            {
                "date":"2025-03-11",
                "item":"Android" 
            }
        ]
}
"""

json_data = json.loads(data)
print(json_data)
print(json_data["history"][0]["date"])
# Out:
# {'id': '01', 'language': 'python', 'edittion': 'third', 'author': 'David', 'history': [{'date': '2025-07-16', 'item': 'iPhone'}, {'date': '2025-03-11', 'item': 'Android'}]}
# 2025-07-16

# %%
import json

data = """
{
    "lastBuildDate": "Wed, 16 Jul 2025 13:19:53 +0900",
    "total": 1261632,
    "start": 1,
    "display": 10,
    "items": [
        {
            "title": "[비비앙] 월넛크릭그린 오 드 퍼퓸 EDP 10ml 20250423-2",
            "link": "https://link.musinsa.com/app/goods/4442601?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}",
            "image": "https://shopping-phinf.pstatic.net/main_5038779/50387791565.jpg",
            "lprice": "41900",
            "hprice": "",
            "mallName": "무신사",
            "productId": "50387791565",
            "productType": "2",
            "brand": "비비앙",
            "maker": "",
            "category1": "화장품/미용",
            "category2": "향수",
            "category3": "여성향수",
            "category4": ""
        },{
            "title": "[보니데] V&amp;A 커버업 랩 수영복 그린(프리) P00000IK",
            "link": "https://link.musinsa.com/app/goods/1968765?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}",
            "image": "https://shopping-phinf.pstatic.net/main_5280188/52801887678.jpg",
            "lprice": "84990",
            "hprice": "",
            "mallName": "무신사",
            "productId": "52801887678",
            "productType": "2",
            "brand": "보니데",
            "maker": "",
            "category1": "스포츠/레저",
            "category2": "수영",
            "category3": "여성수영복",
            "category4": "원피스수영복"
        },
        {
            "title": "[피지컬가먼츠] P2407 메쉬배색 기능성 오버핏반팔 [블랙] P2407",
            "link": "https://link.musinsa.com/app/goods/4128907?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}",
            "image": "https://shopping-phinf.pstatic.net/main_4777637/47776373129.jpg",
            "lprice": "26890",
            "hprice": "",
            "mallName": "무신사",
            "productId": "47776373129",
            "productType": "2",
            "brand": "피지컬가먼츠",
            "maker": "",
            "category1": "패션의류",
            "category2": "남성의류",
            "category3": "티셔츠",
            "category4": ""
        }
        ]
}
"""

json_data = json.loads(data)

for items in json_data["items"] :
    print(items)
# Out:
# {'title': '[비비앙] 월넛크릭그린 오 드 퍼퓸 EDP 10ml 20250423-2', 'link': 'https://link.musinsa.com/app/goods/4442601?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}', 'image': 'https://shopping-phinf.pstatic.net/main_5038779/50387791565.jpg', 'lprice': '41900', 'hprice': '', 'mallName': '무신사', 'productId': '50387791565', 'productType': '2', 'brand': '비비앙', 'maker': '', 'category1': '화장품/미용', 'category2': '향수', 'category3': '여성향수', 'category4': ''}
# {'title': '[보니데] V&amp;A 커버업 랩 수영복 그린(프리) P00000IK', 'link': 'https://link.musinsa.com/app/goods/1968765?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}', 'image': 'https://shopping-phinf.pstatic.net/main_5280188/52801887678.jpg', 'lprice': '84990', 'hprice': '', 'mallName': '무신사', 'productId': '52801887678', 'productType': '2', 'brand': '보니데', 'maker': '', 'category1': '스포츠/레저', 'category2': '수영', 'category3': '여성수영복', 'category4': '원피스수영복'}
# ...

# %%
import requests
import pprint#프리티어프린트 라이브러리 출력 결과물 이쁘게 정렬
import openpyxl

client_id = "c5wR2X6ozk5o0spe5AJb"
client_secret = "cSMgfZuvPV"
start, num = 1, 0

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions["B"].width = 100
excel_sheet.column_dimensions["C"].width = 100
excel_sheet.append(["No", "제목", "링크"])

for index in range(10) :
    start_number = start + (index * 100)
    #? -> 파라미터 시작, 하나의 값 종료 후 &로 구분
    naver_open_api = "https://openapi.naver.com/v1/search/shop.json?query=무신사&display=100&start=" + str(start_number)
    header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}#헤더에 들어갈 값을 딕셔너리 형태로 선언
    
    res = requests.get(naver_open_api, headers=header_params)
    
    if res.status_code == 200 :
        data = res.json()
        # pprint.pp(data)
        # print(data["items"][0]["title"])
        for item in data["items"] :
            num += 1
            excel_sheet.append([num, item["title"], item["link"]])
            print(item)
            # pprint.pp(item["title"])
    else :
        print("Error Code: ", res.status_code)

excel_file.save("shopping_with_무신사1.xlsx")
excel_file.close()
# Out:
# {'title': '[비비앙] 월넛크릭그린 오 드 퍼퓸 EDP 10ml 20250423-2', 'link': 'https://link.musinsa.com/app/goods/4442601?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}', 'image': 'https://shopping-phinf.pstatic.net/main_5038779/50387791565.jpg', 'lprice': '41900', 'hprice': '', 'mallName': '무신사', 'productId': '50387791565', 'productType': '2', 'brand': '비비앙', 'maker': '', 'category1': '화장품/미용', 'category2': '향수', 'category3': '여성향수', 'category4': ''}
# {'title': '[보니데] V&amp;A 커버업 랩 수영복 그린(프리) P00000IK', 'link': 'https://link.musinsa.com/app/goods/1968765?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}', 'image': 'https://shopping-phinf.pstatic.net/main_5280188/52801887678.jpg', 'lprice': '84990', 'hprice': '', 'mallName': '무신사', 'productId': '52801887678', 'productType': '2', 'brand': '보니데', 'maker': '', 'category1': '스포츠/레저', 'category2': '수영', 'category3': '여성수영복', 'category4': '원피스수영복'}
# ...

# %%
import requests
import pprint#프리티어프린트 라이브러리 출력 결과물 이쁘게 정렬
import openpyxl

client_id = "c5wR2X6ozk5o0spe5AJb"
client_secret = "cSMgfZuvPV"
start, num = 1, 0

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions["B"].width = 100
excel_sheet.column_dimensions["C"].width = 100
excel_sheet.append(["No", "제목", "링크", "블로거 링크"])

for index in range(10) :
    start_number = start + (index * 100)
    #? -> 파라미터 시작, 하나의 값 종료 후 &로 구분
    naver_open_api = "https://openapi.naver.com/v1/search/blog.json?query=후루츠패밀리&display=100&start=" + str(start_number)
    header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}#헤더에 들어갈 값을 딕셔너리 형태로 선언
    
    res = requests.get(naver_open_api, headers=header_params)
    
    if res.status_code == 200 :
        data = res.json()
        # pprint.pp(data)
        # print(data["items"][0]["title"])
        for item in data["items"] :
            num += 1
            excel_sheet.append([num, item["title"], item["link"], item["bloggerlink"]])
            print(num, item["title"], item["link"], item["bloggerlink"])
            # pprint.pp(item["title"])
    else :
        print("Error Code: ", res.status_code)

excel_file.save("blog_with_후루츠패밀리1.xlsx")
excel_file.close()
# Out:
# 1 <b>후루츠 패밀리</b> - 중고거래 앱 실사용 후기, 장단점 https://blog.naver.com/carmin6/223925162220 blog.naver.com/carmin6
# 2 명품 시계, 빈티지, <b>후루츠패밀리</b>, 내돈내산 솔직후기 https://blog.naver.com/kkimyuu/223726958428 blog.naver.com/kkimyuu
# 3 행동경제학/심리 분석 - <b>후루츠 패밀리</b>(Fruits family)...  https://blog.naver.com/iiiiqyshsbs123/223483594051 blog.naver.com/iiiiqyshsbs123
# 4 FruitsFamily <b>후루츠 패밀리</b> 이용 및 구매 후기 https://blog.naver.com/gocks5997/223829095182 blog.naver.com/gocks5997
# 5 패션 중고거래 앱 추천 | <b>후루츠패밀리</b> 판매 및 정산 후기...  https://blog.naver.com/ggeal/223822118438 blog.naver.com/ggeal
# 6 디지털 카메라, 옛날 디카 / 올림푸스 뮤 7040 / <b>후루츠패밀리</b> https://blog.naver.com/nana2jerry/223754483162 blog.naver.com/nana2jerry
# 7 <b>후루츠패밀리</b> 추천인코드 논노드 위시리스트 카고 반바지 쇼츠...  https://blog.naver.com/rlarlxo0930/223538882779 blog.naver.com/rlarlxo0930
# 8 <b>후루츠패밀리</b>에서 득템하기 (90s 스투시 빈티지 모자...  https://blog.naver.com/endolpin/223416363607 blog.naver.com/endolpin
# ...

# %%
import requests
import openpyxl

client_id = "c5wR2X6ozk5o0spe5AJb"
client_secret = "cSMgfZuvPV"
start, num = 1, 0

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions["B"].width = 100
excel_sheet.column_dimensions["C"].width = 100
excel_sheet.append(["No", "제목", "링크"])

for index in range(10) :
    start_number = start + (index * 100)
    #? -> 파라미터 시작, 하나의 값 종료 후 &로 구분
    naver_open_api = "https://openapi.naver.com/v1/search/blog.json?query=무신사&display=100&start=" + str(start_number)
    header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}#헤더에 들어갈 값을 딕셔너리 형태로 선언
    
    res = requests.get(naver_open_api, headers=header_params)
    
    if res.status_code == 200 :
        data = res.json()
        # pprint.pp(data)
        # print(data["items"][0]["title"])
        for item in data["items"] :
            num += 1
            excel_sheet.append([num, item["title"], item["link"]])
            print(num, item["title"], item["link"])
            # pprint.pp(item["title"])
    else :
        print("Error Code: ", res.status_code)

excel_file.save("shopping_with_무신사1.xlsx")
excel_file.close()
# Out:
#   Cell In[100], line 22
#     if res.status_code == 200 :
#     ^
# IndentationError: unexpected indent

# %%
import requests
import openpyxl

url = "https://api.themoviedb.org/3/movie/now_playing?language=ko-kr&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4MTBjMWYzNWViMDMyYTI3Y2UxZWMyOGQ3YWM0NDU4MiIsIm5iZiI6MTc1MjEzOTY3Ny43MzMsInN1YiI6IjY4NmY4NzlkNWFiYmI2OWUzZDlhNTJiOSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.gOokxpsnyVG3tyyNUbCiUo9NegLKn5h0l5_riH60r-k"
}

response = requests.get(url, headers=headers)

for item in response :
    print(item)
# Out:
# b'{"dates":{"maximum":"2025-07-23","minimum":"2025-06-11"},"page":1,"results":[{"adult":false,"backdrop_path":"/nKyBbFSooRPTJVqjrD'
# b'teD1lF733.jpg","genre_ids":[28,12,18],"id":1011477,"original_language":"en","original_title":"Karate Kid: Legends","overview":"\xec'
# b'\x84\x9c\xeb\xa1\x9c \xeb\x8b\xa4\xeb\xa5\xb8 \xec\x84\xb8\xeb\x8c\x80\xec\x9d\x98 \xec\x8a\xa4\xec\x8a\xb9 \xeb\xaf\xb8\xec\x8a\xa4\xed\x84\xb0 \xed\x95\x9c(\xec\x84\xb1\xeb\xa3\xa1)\xea\xb3\xbc \xeb\x8b\xa4\xeb\x8b\x88\xec\x97\x98 \xeb\x9d\xbc\xeb\xa3\xa8\xec\x86\x8c(\xeb\x9e\x84\xed\x94\x84 \xeb\xa7\x88\xec\xb9\x98\xec\x98\xa4)\xea\xb0\x80 \xec\x86\x8c\xeb\x85\x84 \xe2\x80\x98\xeb\xa6\xac\xe2\x80\x99\xeb\xa5\xbc \xec\xa4\x91\xec\x8b\xac\xec\x9c\xbc\xeb\xa1\x9c'
# ...

# %%
import requests
import openpyxl

url = "https://api.themoviedb.org/3/movie/now_playing?language=ko-kr&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4MTBjMWYzNWViMDMyYTI3Y2UxZWMyOGQ3YWM0NDU4MiIsIm5iZiI6MTc1MjEzOTY3Ny43MzMsInN1YiI6IjY4NmY4NzlkNWFiYmI2OWUzZDlhNTJiOSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.gOokxpsnyVG3tyyNUbCiUo9NegLKn5h0l5_riH60r-k"
}

response = requests.get(url, headers=headers)

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions["A"].width = 30
excel_sheet.column_dimensions["B"].width = 20
excel_sheet.column_dimensions["C"].width = 50
excel_sheet.column_dimensions["D"].width = 10
excel_sheet.append(["타이틀", "개봉일", "오버뷰", "평점"])

#data = response.json()

for item in response.json()["results"] :
    excel_sheet.append([item["title"], item["release_date"], item["overview"], item["vote_average"]])
    print(item["title"], item["release_date"], item["vote_average"])

excel_file.save("영화정보.xlsx")
excel_file.close()
# Out:
# 가라데 키드: 레전드 2025-05-08 7.309
# 어쩌다 파트너 2025-07-10 5.63
# 슈퍼맨 2025-07-09 7.4
# 발레리나 2025-06-04 7.464
# 아이스 로드: 벤전스 2025-06-27 6.926
# 올드 가드 2 2025-07-01 6.075
# 지암 2025-07-09 6.62
# 쥬라기 월드: 새로운 시작 2025-07-01 6.37
# 국가 원수 2025-07-02 6.976
# 케이팝 데몬 헌터스 2025-06-20 8.621
# Dora and the Search for Sol Dorado 2025-07-02 7.127
# 드래곤 길들이기 2025-06-06 7.974
# F1 더 무비 2025-06-25 7.6
# 좀비스 4: 뱀파이어의 등장 2025-07-10 6.775
# 브링 허 백 2025-05-28 7.4
# 브릭 2025-07-09 5.743
# 마디아의 데스티네이션 웨딩 2025-07-10 5.8
# 리추얼 2025-04-18 5.96
# 씨너스: 죄인들 2025-04-16 7.6
# 28년 후 2025-06-18 7.144
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[139], line 27
#      24     excel_sheet.append([item["title"], item["release_date"], item["overview"], item["vote_average"]])
#      25     print(item["title"], item["release_date"], item["vote_average"])
# ---> 27 excel_file.save("영화정보.xlsx")
# ...
