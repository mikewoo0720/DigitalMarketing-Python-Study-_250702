# %% [markdown]
# - 크롤링에서 어려운 부분(시스템)
#   1. 웹 사이트 구조가 굉장히 복잡한 경우
#   2. 라이브러리나 프레임워크로 만들어진 웹 페이지들은 싱글플레이 어플리케이션 방식인데 크롤링이 안된다. 셀레늄
#   3. 그리고 함부로 데이터를 가져갈 수 없도록 제한을 걸어두었다.
# - 문법적인부분
#   1. 직접 연습해보지 않으면 잘 할 수 없다.
#   2. 개념은 떨쳐버리고 몸과 손이 반응할 수 있도록 반복숙달하자
#
# - 파이썬을 활용해서 특정 웹사이트 내 요소를 크롤링 해오면, 해당 값 자료형태 > 객체의 형태를 띄게 => 객체의 속성 혹은 메서드 함수를 사용가능!!!
#
# - 파이썬을 활용한 크롤링 방법론
#   1. html 문서 구조 파악
#      - 태그들이 주로 반복 사용되는 경우
#      - find() // find_all()
#   2. CSS Selector(*선택자) 활용
#      - html 내 태그 혹은 클래스, 아이디 요소를 css 파일에서 선택해서 무언가를 하고자 할때, 명칭 => 선택자
#      - ul > li // li
#      - - 뎁스가 깊거나 구문이 길 경우 Selector를 활용하면 좀더 정확한 타겟을 크롤링 할 수 있다.
# - select() ⇒ 기본적으로 class 속성을 가지고 있는 선택자들을 찾아와서 반복문을 사용하고 싶은경우
# - select_one() ⇒ id 속성과 같이 문서상에 한 번밖에 사용을 하지 못하는 경우에 크롤링하고 싶을때

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get("https://crawlingtest.netlify.app/")
soup = BeautifulSoup(res.content, "html.parser")

titles = soup.find_all("li", class_="course")

for title in titles :
    print(title.get_text())
# Out:
# (왕초보) - 클래스 소개
#
#
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
#
#
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
#
#
# (왕초보) - 초간단 페이지 만들어보기
#
#
# (왕초보) - 이쁘게 테마 적용해보기
#
#
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지
#           만들기
#
#
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지
#           꾸며보기
#
#
# (초급) - 강사가 실제 사용하는 자동 프로그램 소개 [2]
#
#
# (초급) - 필요한 프로그램 설치 시연 [5]
#
#
# (초급) - 데이터를 엑셀 파일로 만들기 [9]
#
#
# (초급) -     엑셀 파일 이쁘게! 이쁘게! [8]
#
#
# (초급) -     나대신 주기적으로 파이썬 프로그램
#           실행하기 [7]
#
#
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기 [40]
#
#
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기
#           [12]
#
#
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기 [42]
#
#
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버
#           블로그/트위터에 홍보하기 [412]

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get("https://crawlingtest.netlify.app/")
soup = BeautifulSoup(res.content, "html.parser")

titles1 = soup.find("ul", id="hobby_course_list")
titles2 = soup.find("ul", id="dev_course_list")

all_titles = soup.find_all("li", class_="course")

for title in titles1 :
    print(title.get_text())

for title in titles2 :
    print(title.get_text())
# Out:
# (왕초보) - 클래스 소개
#
#
#
#
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
#
#
#
#
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
#
#
#
#
# (왕초보) - 초간단 페이지 만들어보기
#
#
#
#
# (왕초보) - 이쁘게 테마 적용해보기
#
#
#
#
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지
#           만들기
#
#
#
#
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지
#           꾸며보기
#
#
#
#
#
#
# (초급) - 강사가 실제 사용하는 자동 프로그램 소개 [2]
#
#
#
#
# (초급) - 필요한 프로그램 설치 시연 [5]
#
#
#
#
# (초급) - 데이터를 엑셀 파일로 만들기 [9]
#
#
#
#
# (초급) -     엑셀 파일 이쁘게! 이쁘게! [8]
#
#
#
#
# (초급) -     나대신 주기적으로 파이썬 프로그램
#           실행하기 [7]
#
#
#
#
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기 [40]
#
#
#
#
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기
#           [12]
#
#
#
#
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기 [42]
#
#
#
#
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버
#           블로그/트위터에 홍보하기 [412]

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get("https://crawlingtest.netlify.app/")
soup = BeautifulSoup(res.content, "html.parser")

section = soup.find("ul", id="hobby_course_list").find_all("li", "course")#메서드 체이닝 기법
#titles = section.find_all("li", "course")

for title in titles :
    print(title.get_text().split("-")[1])
# Out:
#  클래스 소개
#
#  블로그 개발 필요한 준비물 준비하기
#
#  Github pages 설정해서 블로그 첫 페이지 만들어보기
#
#  초간단 페이지 만들어보기
#
#  이쁘게 테마 적용해보기
#
#  마크다운 기초 이해하고, 실제 나만의 블로그 페이지
#           만들기
#
#  다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지
#           꾸며보기
#
#  강사가 실제 사용하는 자동 프로그램 소개 [2]
#
#  필요한 프로그램 설치 시연 [5]
#
#  데이터를 엑셀 파일로 만들기 [9]
#
#      엑셀 파일 이쁘게! 이쁘게! [8]
#
#      나대신 주기적으로 파이썬 프로그램
#           실행하기 [7]
#
#  파이썬으로 슬랙(slack) 메신저에 글쓰기 [40]
#
#  웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기
#           [12]
#
#  네이버 API 사용해서, 블로그에 글쓰기 [42]
#
#  자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버
#           블로그/트위터에 홍보하기 [412]

# %% [markdown]
# #### 파이썬 크롤링 미션
# - https://crawlingtest.netlify.app/ 해당 사이트에서 course라는 클래스값을 가지고 있는 li태그 내부 텍스트를 출력하세요. 단, 난이도 단계 제외하고 실제 제목들만 가져와라

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get("https://crawlingtest.netlify.app/")
soup = BeautifulSoup(res.content, "html.parser")

titles = soup.find_all("li", "course")

title_list = []

for title in titles :
    title_list.append(title.get_text(separator=' ', strip=True))


for item in title_list :
    print(item.split("-")[1].strip(""))
# for title in titles :
#     print(title.get_text())
# Out:
#  클래스 소개
#  블로그 개발 필요한 준비물 준비하기
#  Github pages 설정해서 블로그 첫 페이지 만들어보기
#  초간단 페이지 만들어보기
#  이쁘게 테마 적용해보기
#  마크다운 기초 이해하고, 실제 나만의 블로그 페이지
#           만들기
#  다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지
#           꾸며보기
#  강사가 실제 사용하는 자동 프로그램 소개 [2]
#  필요한 프로그램 설치 시연 [5]
#  데이터를 엑셀 파일로 만들기 [9]
#      엑셀 파일 이쁘게! 이쁘게! [8]
#      나대신 주기적으로 파이썬 프로그램
#           실행하기 [7]
#  파이썬으로 슬랙(slack) 메신저에 글쓰기 [40]
#  웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기
#           [12]
#  네이버 API 사용해서, 블로그에 글쓰기 [42]
#  자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버
#           블로그/트위터에 홍보하기 [412]

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get("https://crawlingtest.netlify.app/")
soup = BeautifulSoup(res.content, "html.parser")

titles = soup.find_all("li", "course")

for title in titles :
    print(title.get_text().split("-")[-1].split("[")[0].replace("\n", " ").replace(" ", "").strip())
# Out:
# 클래스소개
# 블로그개발필요한준비물준비하기
# Githubpages설정해서블로그첫페이지만들어보기
# 초간단페이지만들어보기
# 이쁘게테마적용해보기
# 마크다운기초이해하고,실제나만의블로그페이지만들기
# 다양한마크다운기법익혀보며,나만의블로그페이지꾸며보기
# 강사가실제사용하는자동프로그램소개
# 필요한프로그램설치시연
# 데이터를엑셀파일로만들기
# 엑셀파일이쁘게!이쁘게!
# 나대신주기적으로파이썬프로그램실행하기
# 파이썬으로슬랙(slack)메신저에글쓰기
# 웹사이트변경사항주기적으로체크해서,메신저로알람주기
# 네이버API사용해서,블로그에글쓰기
# 자동으로쿠팡파트너스API로가져온상품정보,네이버블로그/트위터에홍보하기

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get("https://crawlingtest.netlify.app/")
soup = BeautifulSoup(res.content, "html.parser")

titles = soup.find_all("li", "course")

for idx, title in enumerate(titles, 1) :
    print(f"{idx}. {title.get_text().split("-")[-1].split("[")[0].replace("\n", " ").replace(" ", "").strip()}")

# for idx, title in enumerate(section, 1):  # 1부터 시작
#     text = title.get_text(separator=' ', strip=True)
#     cleaned_text = re.sub(r'\s+', ' ', text)  # 개행/들여쓰기 정리
#     print(f"{idx}. {cleaned_text}")
# Out:
# 1. 클래스소개
# 2. 블로그개발필요한준비물준비하기
# 3. Githubpages설정해서블로그첫페이지만들어보기
# 4. 초간단페이지만들어보기
# 5. 이쁘게테마적용해보기
# 6. 마크다운기초이해하고,실제나만의블로그페이지만들기
# 7. 다양한마크다운기법익혀보며,나만의블로그페이지꾸며보기
# 8. 강사가실제사용하는자동프로그램소개
# 9. 필요한프로그램설치시연
# 10. 데이터를엑셀파일로만들기
# 11. 엑셀파일이쁘게!이쁘게!
# 12. 나대신주기적으로파이썬프로그램실행하기
# 13. 파이썬으로슬랙(slack)메신저에글쓰기
# 14. 웹사이트변경사항주기적으로체크해서,메신저로알람주기
# 15. 네이버API사용해서,블로그에글쓰기
# 16. 자동으로쿠팡파트너스API로가져온상품정보,네이버블로그/트위터에홍보하기
