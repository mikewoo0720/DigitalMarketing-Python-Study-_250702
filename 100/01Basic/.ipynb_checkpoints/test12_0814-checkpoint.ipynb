# %%
#인터파크
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time

service = Service(ChromeDriverManager().install())

options = Options()
# options.add_argument("--headless")  
options.add_argument("--window-size=1920x1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)
driver.get("https://tickets.interpark.com/contents/ranking?genre=MUSICAL")
time.sleep(2)

time_infos = driver.find_elements(By.CSS_SELECTOR, "div.responsive-ranking-list_imageWrap__ROlYW")

for idx, elem in enumerate(elements, start=1):
    try:
        driver.execute_script("arguments[0].scrollIntoView(true);", elem)  # 화면에 스크롤
        time.sleep(0.5)  # 스크롤 안정화 대기
        elem.click()
        print(f"{idx}번째 요소 클릭 완료")
        time.sleep(1)  # 클릭 후 대기 (필요시 조정)
    except Exception as e:
        print(f"{idx}번째 요소 클릭 실패: {e}")

time.sleep(2)
driver.quit()
