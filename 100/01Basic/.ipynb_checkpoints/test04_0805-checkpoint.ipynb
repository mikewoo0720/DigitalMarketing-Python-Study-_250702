# %%
# 네이버 지식백과에서 '콘텐츠 마케팅' 항목의 본문 요약을 추출하세요.
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import urllib
import time

service = Service(ChromeDriverManager().install())

options = Options()
options.add_argument("--headless")
options.add_argument("--window-size=1920x1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)

query = "entry.naver?docId=2275742&cid=42266&categoryId=51204"
encoded_query = urllib.parse.quote(query)

url = f"https://terms.naver.com/{query}"
driver.get(url)
time.sleep(1)

element = driver.find_element(By.CSS_SELECTOR, "p.txt")

print(element.text)
# Out:
# 콘텐츠산업은 21세기 창조경제를 견인할 핵심 성장 동력으로 각광받고 있고, 디지털 미디어의 다원화로 산업이 성장하고 있지만, 동시에 콘텐츠 사업자간 경쟁은 더욱 치열해지고 있다. 콘텐츠 기업은 사업 분야와 역량에 따라 제작, 유통, 단말 등 강점을 갖는 사업 영역이 있다. 성장과 경쟁의 압박 속에서 이익의 창출이 어려워질수록 각 산업의 핵심가치에 기반한 전략이 빛을 발하게 되는데, 콘텐츠산업의 중심에는 소비자, 즉 고객이 존재한다. 고객과 직접 대면하며, 고객과의 관계 속에서 미래성장의 가능성을 발견하는 콘텐츠사업자들의 핵심적인 10대 전략을 분석하고, 콘텐츠산업의 미래성장 가능성을 진단한다.
#
# 콘텐츠산업은 21세기 창조경제를 견인할 핵심 성장 동력으로 각광받고 있고, 디지털 미디어의 다원화로 산업이 성장하고 있지만, 동시에 콘텐츠 사업자간 경쟁은 더욱 치열해지고 있다. 콘텐츠 기업은 사업 분야와 역량에 따라 제작, 유통, 단말 등 강점을 갖는 사업 영역이 있다. 성장과 경쟁의 압박 속에서 이익의 창출이 어려워질수록 각 산업의 핵심가치에 기반한 전략이 빛을 발하게 되는데, 콘텐츠산업의 중심에는 소비자, 즉 고객이 존재한다. 고객과 직접 대면하며, 고객과의 관계 속에서 미래성장의 가능성을 발견하는 콘텐츠사업자들의 핵심적인 10대 전략을 분석하고, 콘텐츠산업의 미래성장 가능성을 진단한다.

# %%
#한국관광공사 '추천 여행지' 페이지에서 지역별 여행지명을 수집하세요.
#17개 클릭, 먼저 메인페이지 크롤링 가능여부 확인
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import urllib
import time

service = Service(ChromeDriverManager().install())

options = Options()
# options.add_argument("--headless")
# options.add_argument('--disable-gpu')
options.add_argument("--window-size=1920x1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)

query = "area.do"
encoded_query = urllib.parse.quote(query)

url = f"https://korean.visitkorea.or.kr/main/{query}"
driver.get(url)
time.sleep(2)

fav_button = driver.find_element(By.CSS_SELECTOR, "div.swiper-wrapper")
# fav_button = driver.find_element(By.XPATH, "#zone8 > a")
print(fav_button.text)
# fav_button.click()
time.sleep(2)

# element = driver.find_element(By.CSS_SELECTOR, "p.txt")
driver.quit()
# Out:
# 경남
# 전북
# 전남
# 제주
# 세종
# 전국
# 서울
# 인천
# 대전
# 대구
# 광주

# %%
#브런치 홈페이지에서 인기 글 제목을 수집하세요.
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import urllib
import time

service = Service(ChromeDriverManager().install())

options = Options()
options.add_argument("--headless")
options.add_argument("--window-size=1920x1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)

query = "#sun"
encoded_query = urllib.parse.quote(query)

# url = f"https://brunch.co.kr/serial/list{query}#PUBLISH_TIME"
# driver.get(url)
# time.sleep(1)
weeks = ["#mon", "#tue", "#wed", "#thu", "#fri", "#sat", "#sun"]
# titles= driver.find_elements(By.CSS_SELECTOR, "strong.tit_info")

for week in weeks :
    driver.get(f"https://brunch.co.kr/serial/list{week}#PUBLISH_TIME")
    time.sleep(1)
    print(f"\n{week} 베스트\n")
    titles= driver.find_elements(By.CSS_SELECTOR, "strong.tit_info")
    for i, title in enumerate(titles, 1) :
        print(f"{i}. {title.text.strip().replace("\n","")}")
# Out:
# #mon 베스트
#
# 1. 일 없는 나를 받아들이다
# 2. 여행
# 3. 그 50대 남자
# 4. 가족이라는 랜덤게임
# 5. 살기 위한 떡라면론
# 6. 몬세랏에서 다시 찾은 삶의 속도
# 7. 산후관리사님을 부르는게 좋을까?
# 8. [출산이야기: 2화] 나를 타인에게 맡기다
# 9. 트렌드를 거절하고, 나만의 공간을 만들다
# 10. 운동회 1등의 기적
# 11. AUG, 1. 여름휴가
# 12. 동사
# 13. 인간관계는 택배 상자
# 14. 06. 병동 철가방, 그리고 말랑말랑한 마음
# 15. 다시 돌아온 공포의 심해탐험. <서브노티카2>
# 16. 아빠! 공부 안 하는 학교 있다고 하지 않았어?
# 17. 10화-같은 듯 다른 ‘사극’, 古装剧와 历史剧
# 18. 억눌렀던 감정들을 쏟아내다
# 19. 김밥과 한라봉 사이
# 20. 지금 여기 아닌 어딘가
#
# #tue 베스트
#
# 1. 일 없는 나를 받아들이다
# 2. 여행
# 3. 그 50대 남자
# 4. 가족이라는 랜덤게임
# 5. 살기 위한 떡라면론
# 6. 몬세랏에서 다시 찾은 삶의 속도
# 7. 산후관리사님을 부르는게 좋을까?
# 8. [출산이야기: 2화] 나를 타인에게 맡기다
# 9. 트렌드를 거절하고, 나만의 공간을 만들다
# 10. 운동회 1등의 기적
# 11. AUG, 1. 여름휴가
# 12. 동사
# 13. 인간관계는 택배 상자
# 14. 06. 병동 철가방, 그리고 말랑말랑한 마음
# 15. 다시 돌아온 공포의 심해탐험. <서브노티카2>
# 16. 아빠! 공부 안 하는 학교 있다고 하지 않았어?
# 17. 10화-같은 듯 다른 ‘사극’, 古装剧와 历史剧
# 18. 억눌렀던 감정들을 쏟아내다
# 19. 김밥과 한라봉 사이
# 20. 지금 여기 아닌 어딘가
#
# #wed 베스트
#
# 1. 일 없는 나를 받아들이다
# 2. 여행
# 3. 그 50대 남자
# 4. 가족이라는 랜덤게임
# 5. 살기 위한 떡라면론
# 6. 몬세랏에서 다시 찾은 삶의 속도
# ...

# %%
#교보문고 경제 분야 주간 베스트셀러 도서 제목 수집하세요.
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import urllib
import time

service = Service(ChromeDriverManager().install())

options = Options()
options.add_argument("--headless")
options.add_argument("--window-size=1920x1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)

query = "bestseller/total/weekly/economics"
encoded_query = urllib.parse.quote(query)

url = f"https://store.kyobobook.co.kr/{query}"
driver.get(url)
time.sleep(1)

titles= driver.find_elements(By.CSS_SELECTOR, "div.flex a.prod_link.line-clamp-2")

for i, title in enumerate(titles, 1) :
    print(f"{i}. {title.text}")
# Out:
# 1. 박곰희 연금 부자 수업
# 2. 세계 경제 지각 변동
# 3. 새로운 질서
# 4. 글로벌 주식 투자 빅 시프트
# 5. 부의 전략 수업
# 6. 워런 버핏 웨이
# 7. 돈의 심리학(30만 부 기념 스페셜 에디션)
# 8. 미치도록 보고 싶었던 돈의 얼굴
# 9. 인생을 바꾸는 최고의 ETF
# 10. 단 3개의 미국 ETF로 은퇴하라
# 11. 박태웅의 AI 강의 2025
# 12. 나는 0원으로 강남 건물주보다 월세 많이 받는 온라인 건물주로 산다
# 13. 돈의 속성(400쇄 리커버에디션)
# 14. 빅 사이클
# 15. 결핍은 우리를 어떻게 변화시키는가
# 16. 자본주의
# 17. 재테크농부의 올라운드 투자
# 18. AI 에이전트 트렌드&활용백과
# 19. 초보자를 단숨에 고수로 만드는 주식투자 핵심 수업
# 20. 엔비디아 젠슨 황, 생각하는 기계

# %%
#멜론 차트 1~10위 노래 제목과 가수를 수집하세요.
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import urllib
import time

service = Service(ChromeDriverManager().install())

options = Options()
options.add_argument("--headless")
options.add_argument("--window-size=1920x1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)

query = "chart/index.htm"
encoded_query = urllib.parse.quote(query)

url = f"https://www.melon.com/{query}"
driver.get(url)
time.sleep(1)

titles = driver.find_elements(By.CSS_SELECTOR, "div.wrap_song_info")[:10]

for idx, title in enumerate(titles, 1):
    song = title.find_element(By.CSS_SELECTOR, "div.ellipsis.rank01 a").text
    print(f"{idx}. {song}")
# Out:
# 1. Golden
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[19], line 31
#      28 titles = driver.find_elements(By.CSS_SELECTOR, "div.wrap_song_info")[:10]
#      30 for idx, title in enumerate(titles, 1):
# ---> 31     song = title.find_element(By.CSS_SELECTOR, "div.ellipsis.rank01 a").text
#      32     print(f"{idx}. {song}")
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:602, in WebElement.find_element(self, by, value)
#     576 """Find an element given a By strategy and locator.
#     577
#     578 Parameters:
#    (...)
#     599     The first matching `WebElement` found on the page.
#     600 """
#     601 by, value = self._parent.locator_converter.convert(by, value)
# --> 602 return self._execute(Command.FIND_CHILD_ELEMENT, {"using": by, "value": value})["value"]
#
# ...

# %%
import requests
from bs4 import BeautifulSoup

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)",
    "Referer": "https://www.melon.com/index.htm"
}

url = "https://www.melon.com/chart/index.htm"

res = requests.get(url, headers=headers)
res.encoding = 'utf-8'
soup = BeautifulSoup(res.text, "html.parser")

songs = soup.select("tr.lst50")[:10]

for idx, song in enumerate(songs, 1):
    title = song.select_one("div.ellipsis.rank01 a").text.strip()
    artist = song.select_one("div.ellipsis.rank02 a").text.strip()
    print(f"{idx}. {title} - {artist}")
# Out:
# 1. Golden - HUNTR/X
# 2. 뛰어(JUMP) - BLACKPINK
# 3. Soda Pop - KPop Demon Hunters Cast
# 4. FAMOUS - ALLDAY PROJECT
# 5. Dirty Work - aespa
# 6. Drowning - WOODZ
# 7. 시작의 아이 - 마크툽 (MAKTUB)
# 8. 너에게 닿기를 - 10CM
# 9. Your Idol - KPop Demon Hunters Cast
# 10. WICKED - ALLDAY PROJECT
