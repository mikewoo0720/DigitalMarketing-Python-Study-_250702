# %%
#구글 뉴스에서 'ChatGPT' 관련 기사 제목을 수집하세요.
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import urllib
import time

service = Service(ChromeDriverManager().install())

options = Options()
options.add_argument("--headless")
options.add_argument("--window-size=1920x1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)

query = "?for=chatgpt"
encoded_query = urllib.parse.quote(query)

driver.get(f"https://news.google.com/search{query}")
time.sleep(1)

titles = driver.find_elements(By.CSS_SELECTOR, "a.JtKRv ")

for i, title in enumerate(titles[:5], 1) :
    print(f"{i}. {title.text}")

driver.quit()
# Out:
# 1. 미국 정부, 각 부처에 ChatGPT 통합 도입 발표
# 2. 공부 모드를 소개합니다
# 3. OpenAI, 연방 기관에 ChatGPT Enterprise 1달러에 제공 By Investing.com
# 4. 세미나허브, 9월 2일 ‘AI+ChatGPT 실전 활용 클래스’ 온·오프라인 동시 개최
# 5. 미국 정부, ChatGPT Enterprise 버전 단돈 1달러에 구매 가능

# %%
#서울시청 홈페이지에서 공지사항 제목 10개를 수집하세요.
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import urllib
import time

service = Service(ChromeDriverManager().install())

options = Options()
options.add_argument("--headless")
options.add_argument("--window-size=1920x1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)

query = "?for=chatgpt"
encoded_query = urllib.parse.quote(query)

driver.get(f"https://news.google.com/search{query}")
time.sleep(1)

titles = driver.find_elements(By.CSS_SELECTOR, "a.JtKRv ")

for i, title in enumerate(titles[:5], 1) :
    print(f"{i}. {title.text}")

driver.quit()

# %%
#쿠팡에서 '노트북' 검색결과의 리뷰 수가 100개 이상인 상품만 수집하세요. /막힘

# %%
#인스타그램에 로그인 후 '#여행' 해시태그로 게시물 20개의 텍스트를 수집하세요.
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import urllib
import time

service = Service(ChromeDriverManager().install())

options = Options()
options.add_argument("--headless")
options.add_argument("--window-size=1920x1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)

query = "?for=chatgpt"
encoded_query = urllib.parse.quote(query)

driver.get(f"https://news.google.com/search{query}")
time.sleep(1)

titles = driver.find_elements(By.CSS_SELECTOR, "a.JtKRv ")

for i, title in enumerate(titles[:5], 1) :
    print(f"{i}. {title.text}")

driver.quit()

# %%
#트위터 로그인 후 '#디지털마케팅' 트윗 50개의 텍스트를 수집하세요.
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import urllib
import time

service = Service(ChromeDriverManager().install())

options = Options()
options.add_argument("--headless")
options.add_argument("--window-size=1920x1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)

query = "?for=chatgpt"
encoded_query = urllib.parse.quote(query)

driver.get(f"https://news.google.com/search{query}")
time.sleep(1)

titles = driver.find_elements(By.CSS_SELECTOR, "a.JtKRv ")

for i, title in enumerate(titles[:5], 1) :
    print(f"{i}. {title.text}")

driver.quit()
