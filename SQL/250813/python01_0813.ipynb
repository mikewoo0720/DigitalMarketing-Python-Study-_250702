# %%
import pymysql

db = pymysql.connect(
    host = "localhost",
    port = 3306,
    user = "root",
    passwd = "dnwhdgus9#",
    db = "ecommerce_v1",
    charset = "utf8"
)

# %%
db

# %%
ecommercev1 = db.cursor()

# %%
ecommercev1

# %%
sql = """
    CREATE TABLE product(
        PRODUCT_CODE VARCHAR(20) PRIMARY KEY NOT NULL,
        TITLE VARCHAR(200) NOT NULL,
        ORI_PRICE INT,
        DISCOUNT_PRICE INT,
        DISCOUNT_PERCENT INT,
        DELIVERY VARCHAR(2)
    );
"""

# %%
sql
# Out:
# '\n    CREATE TABLE product(\n        PRODUCT_CODE VARCHAR(20) PRIMARY KEY NOT NULL,\n        TITLE VARCHAR(200) NOT NULL,\n        ORI_PRICE INT,\n        DISCOUNT_PRICE INT,\n        DISCOUNT_PERCENT INT,\n        DELIVERY VARCHAR(2)\n    );\n'

# %%
ecommercev1.execute(sql)
# Out:
# 0

# %%
db.commit()
db.close()

# %%
import pymysql

db = pymysql.connect(
    host = "localhost",
    port = 3306,
    user = "root",
    passwd = "dnwhdgus9#",
    db = "ecommerce_v1",
    charset = "utf8"
)

# %%
cursor = db.cursor()

# %%
for index in range(10) :
    product_code = 213413150 + index + 1
    SQL = f"""
        INSERT INTO product VALUES(
            '{product_code}',
            '스위트바니 여름신상 5900원 ~ 롱원피스/티셔츠/긴팔/반팔',
            23000,
            6900,
            70,
            'F'
        )
        
        
    """
    cursor.execute(SQL)

# %%
db.commit()

# %%
db.close()
